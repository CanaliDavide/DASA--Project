# %%
import Utility as ut
import pandas as pd

# %% [markdown]
# # CYCLE A

# %%
cycleA = pd.read_csv("./Data/Chickens data/WithMacro/CycleA-Clean.csv")

# %% [markdown]
# ## DeathPerc - Eggs

# %%
hl_death_eggs = ut.HierarchicalClutering(cycleA, ["DeathPerc", "Eggs"])

# %%
dl_death_eggs = ut.DensityClustering(cycleA, ["DeathPerc", "Eggs"])

# %%
kml_death_eggs = ut.KMeanClustering(cycleA, ["DeathPerc", "Eggs"])

# %%
ut.TemporalCluster(cycleA, kml_death_eggs, ["DeathPerc", "Eggs"], "AvgTemp")
# Out:
# Counter({1: 333, 0: 294})

# %% [markdown]
# ## Laied - DeathPerc

# %%
hl_laied_death = ut.HierarchicalClutering(cycleA, ["Laied", "DeathPerc"])

# %%
dl_laied_death = ut.DensityClustering(cycleA, ["Laied", "DeathPerc"])

# %%
kml_laied_death = ut.KMeanClustering(cycleA, ["Laied", "DeathPerc"])

# %%
ut.TemporalCluster(cycleA, dl_laied_death,  ["Laied", "DeathPerc"], "Laied")
# Out:
# Counter({1: 201, 2: 188, 0: 103, -1: 54, 8: 30, 7: 9, 9: 7, 4: 6, 6: 6, 3: 5, 5: 5, 10: 5, 11: 4, 12: 4})
# Counter({1: 201, 2: 188, 0: 103, -1: 74, 8: 30, 7: 9, 4: 6, 6: 6, 3: 5, 5: 5})

# %% [markdown]
# # Laied - AvgTemp

# %%
hl_laied_temp = ut.HierarchicalClutering(cycleA, ["Laied", "AvgTemp"])

# %%
dl_laied_temp = ut.DensityClustering(cycleA, ["Laied", "AvgTemp"])

# %%
kml_laied_temp = ut.KMeanClustering(cycleA, ["Laied", "AvgTemp"])

# %%
ut.TemporalCluster(cycleA, dl_laied_temp,  ["Laied", "AvgTemp"], "Laied")
# Out:
# Counter({0: 246, 2: 190, 3: 140, -1: 38, 1: 13})
# Counter({0: 246, 2: 190, 3: 140, -1: 38, 1: 13})

# %% [markdown]
# # DeathPerc - Water

# %%
hl_death_water = ut.HierarchicalClutering(cycleA, ["DeathPerc", "Water"])

# %%
dl_death_water = ut.DensityClustering(cycleA, ["DeathPerc", "Water"])

# %%
kml_death_water = ut.KMeanClustering(cycleA,) ["DeathPerc", "Water"]

# %%
ut.TemporalCluster(cycleA, dl_death_water,  ["DeathPerc", "Water"], "DeathPerc")
# Out:
# Counter({2: 288, 6: 148, 3: 125, -1: 39, 4: 8, 0: 6, 1: 5, 5: 4, 7: 4})
# Counter({2: 288, 6: 148, 3: 125, -1: 66})
# [-1, 2, 3, 6]
