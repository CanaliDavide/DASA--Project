# %%
import Utility as ut
import pandas as pd

# %% [markdown]
# # CYCLE B

# %% [markdown]
# ## Hierarcical

# %%
cycleB = pd.read_csv("./Data/Chickens data/WithMacro/CycleB-Clean.csv")

# %%
hirerchical_labels_2 = ut.HierarchicalClutering(cycleB, ["DeathPerc", "Eggs"])

# %%
ut.TemporalCluster(cycleB, hirerchical_labels_2, ["DeathPerc", "Eggs"], "DeathPerc")
# Out:
# Counter({0: 299, 2: 186, 3: 61, 1: 40})

# %%
ut.TemporalCluster(cycleB, hirerchical_labels_2, ["DeathPerc", "Eggs"], "AvgHum")
# Out:
# Counter({0: 299, 2: 186, 3: 61, 1: 40})
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %% [markdown]
# ## Density

# %%
density_labels = ut.DensityClustering(cycleB, ["DeathPerc", "Eggs"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [44], line 1
# ----> 1 density_labels = ut.DensityClustering(cycleB, ["DeathPerc", "Eggs"])
#
# File c:\Users\fcami\OneDrive - Politecnico di Milano\ANNO 4\Data Analytics For Agricolture\Project\Utility.py:238, in DensityClustering(dataSet, attributes)
#     235 plt.show()
#     237 eps = input("Epsilon?")
# --> 238 cluster = DBSCAN(eps=float(eps), min_samples=4).fit(data)
#     240 data_labels = cluster.labels_
#     241 sns.scatterplot(x=attributes[0], y=attributes[1],data=data, hue=data_labels,legend="full", palette="rainbow").set_title('Clusters')
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# ## K-means

# %%
kMeans_labels = ut.KMeanClustering(cycleB, ["DeathPerc", "Eggs"])

# %%
ut.TemporalCluster(cycleB, kMeans_labels, ["DeathPerc", "Eggs"], "DeathPerc")
# Out:
# Counter({1: 301, 0: 285})

# %%
ut.TemporalCluster(cycleB, kMeans_labels, ["DeathPerc", "Eggs"], "Feed")
# Out:
# Counter({1: 301, 0: 285})
