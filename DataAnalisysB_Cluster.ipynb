# %%
import Utility as ut
import pandas as pd

# %% [markdown]
# # CYCLE B

# %%
cycle = pd.read_csv("./Data/Chickens data/WithMacro/CycleB-Clean.csv")

# %% [markdown]
# ## Parameters

# %%
variables_to_cluster = ["Laied", "DeathPerc"]
variable_to_plot_1 = 'DeathPerc'
variavle_to_plot_2 = 'AvgHum'

# %% [markdown]
# ## Hierarcical

# %%
hirerchical_labels_2 = ut.HierarchicalClutering(cycle, variables_to_cluster)

# %%
ut.TemporalCluster(cycle, hirerchical_labels_2, variables_to_cluster, variable_to_plot_1)
# Out:
# Counter({1: 299, 0: 287})

# %%
ut.TemporalCluster(cycle, hirerchical_labels_2, variables_to_cluster, variavle_to_plot_2)
# Out:
# Counter({1: 299, 0: 287})

# %% [markdown]
# ## Density

# %%
density_labels = ut.DensityClustering(cycle, variables_to_cluster)

# %%
ut.TemporalCluster(cycle, density_labels, variables_to_cluster, variable_to_plot_1)
# Out:
# Counter({0: 301, 1: 232, -1: 35, 4: 10, 2: 4, 3: 4})

# %%
ut.TemporalCluster(cycle, density_labels, variables_to_cluster, variable_to_plot_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [79], line 1
# ----> 1 ut.TemporalCluster(cycle, density_labels, variables_to_cluster, variable_to_plot_2)
#
# NameError: name 'variable_to_plot_2' is not defined

# %% [markdown]
# ## K-means

# %%
kMeans_labels = ut.KMeanClustering(cycle, ["DeathPerc", "Eggs"])

# %%
ut.TemporalCluster(cycle, kMeans_labels, variables_to_cluster, variable_to_plot_1)

# %%
ut.TemporalCluster(cycle, kMeans_labels, variables_to_cluster, variable_to_plot_2)
