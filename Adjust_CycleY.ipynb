# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
import Utility

# %% [markdown]
# ## Plot to adjust cycle Y

# %%
cycleY = pd.read_csv("./Data/Chickens data/CycleY-CleanData021222.csv", sep=";")
cY = pd.read_csv("./Data/Chickens data/CycleY-CleanData021222_2.csv", sep=";")

# %%
Utility.EggsPerSeason(cycleY, "Before Y")
Utility.EggsPerSeason(cycleY, "Before Y", True)
Utility.EggsPerSeason(cY, "After Y")
Utility.EggsPerSeason(cY, "After Y", True)

# %% [markdown]
# ## Plot of % death

# %%
#cronological order
cycleY = pd.read_csv("./Data/Chickens data/CycleY-CleanData021222_3.csv", sep=";")
cycleZ = pd.read_csv("./Data/Chickens data/CycleZ-CleanData021222.csv", sep=";")
cycleA = pd.read_csv("./Data/Chickens data/CycleA-CleanData021222.csv", sep=";")
cycleB = pd.read_csv("./Data/Chickens data/CycleB-CleanData021222.csv", sep=";")
cycleC = pd.read_csv("./Data/Chickens data/CycleC-CleanData021222_2.csv", sep=";")

# %%
Utility.CompareVariableInCycles([cycleY.DeathPerc*100, cycleZ.DeathPerc*100, cycleA.DeathPerc*100, cycleB.DeathPerc*100, cycleC.DeathPerc*100], "Death percentage",dayEnd=130, averagePerDays=True, numOfDay=7)
Utility.CompareVariableInCycles([cycleY.Death, cycleZ.Death, cycleA.Death, cycleB.Death, cycleC.Death], "Death",dayEnd=130, averagePerDays=True, numOfDay=7)
