# %%
import sys
sys.path.append('../')

# %reload_ext autoreload
# %autoreload 2

import Utility as ut
import pandas as pd

# %% [markdown]
# ## Cycle selection

# %%
cycle = pd.read_csv("../Data/Chickens data/WithMacro/CycleZ-Clean.csv")
cycle = cycle.drop(columns=["Feed","Water"])
cycle=cycle.rename(columns={"Laied": "Laid"})

# %% [markdown]
# ## Parameters

# %%
variables_to_cluster = ["Laid", "DeathPerc"]
variable_to_plot_1 = 'DeathPerc'
variable_to_plot_2 = 'Laid'

# %% [markdown]
# ## Hierarcical

# %%
hirerchical_labels_2 = ut.HierarchicalClutering(cycle, variables_to_cluster)

# %%
ut.TemporalCluster(cycle, hirerchical_labels_2, variables_to_cluster, variable_to_plot_1,True)
# Out:
# Counter({0: 343, 1: 162})
# [0, 1]

# %%
ut.TemporalCluster(cycle, hirerchical_labels_2, variables_to_cluster, variable_to_plot_2,True)
# Out:
# Counter({0: 343, 1: 162})
# [0, 1]
