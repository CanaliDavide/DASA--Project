# %%
import sys
sys.path.append('../')

import Utility as ut
import pandas as pd

# %% [markdown]
# # CYCLE A

# %%
cycleA = pd.read_csv("../Data/Chickens data/WithMacro/CycleA-Clean.csv")

# %%
hirerchical_labels_2 = ut.HierarchicalClutering(cycleA, ["DeathPerc", "Eggs"])

# %%
density_labels = ut.DensityClustering(cycleA, ["DeathPerc", "Eggs"])

# %%
kMeans_labels = ut.KMeanClustering(cycleA, ["DeathPerc", "Eggs"])
