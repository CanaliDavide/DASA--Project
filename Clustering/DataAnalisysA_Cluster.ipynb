# %%
import sys
sys.path.append('../')

# %reload_ext autoreload
# %autoreload 2

import Utility as ut
import pandas as pd

# %% [markdown]
# # CYCLE A

# %%
cycleA = pd.read_csv("../Data/Chickens data/WithMacro/CycleA-Clean.csv")

# %%
label_h = ut.HierarchicalClutering(cycleA, ["Laied","DeathPerc"])

# %%
label = ut.DensityClustering(cycleA, ["Laied", "DeathPerc"])

# %%
for i in range(len(label)):
    if label[i] > 0:
        label[i] = 1

# %%
ut.TemporalCluster(cycleA, label, ["Laied","DeathPerc"], "DeathPerc")
# Out:
# Counter({0: 304, 1: 285, -1: 38})
# [-1, 0, 1]

# %%
ut.TemporalCluster(cycleA, label, ["Laied","DeathPerc"], "Laied")
# Out:
# Counter({0: 304, 1: 285, -1: 38})
# [-1, 0, 1]
