# %%
import sys
sys.path.append('../')

# %reload_ext autoreload
# %autoreload 2

import Utility as ut
import pandas as pd

# %% [markdown]
# ## Cycle selection

# %%
cycle = pd.read_csv("../Data/Chickens data/WithMacro/CycleX_1-Clean.csv")
cycle = cycle.drop(columns=["Feed","Water"])
cycle=cycle.rename(columns={"Laied": "Laid"})

# %% [markdown]
# ## Parameters

# %%
variables_to_cluster = ["Laid", "DeathPerc"]
variable_to_plot_1 = 'DeathPerc'
variavle_to_plot_2 = 'Laid'

# %% [markdown]
# ## Hierarcical

# %%
hirerchical_labels_2 = ut.HierarchicalClutering(cycle, variables_to_cluster)
# Out:
# c:\Users\canal\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\preprocessing\_data.py:461: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# c:\Users\canal\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\preprocessing\_data.py:462: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)

# %%
ut.TemporalCluster(cycle, hirerchical_labels_2, variables_to_cluster, variable_to_plot_1,True)
# Out:
# c:\Users\canal\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\preprocessing\_data.py:461: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# c:\Users\canal\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\preprocessing\_data.py:462: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)
# Counter({1: 260, 0: 218})
# [0, 1]

# %%
ut.TemporalCluster(cycle, hirerchical_labels_2, variables_to_cluster, variavle_to_plot_2,True)
# Out:
# c:\Users\canal\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\preprocessing\_data.py:461: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# c:\Users\canal\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\preprocessing\_data.py:462: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)
# Counter({1: 260, 0: 218})
# [0, 1]

# %% [markdown]
# ## K-means

# %%
kMeans_labels = ut.KMeanClustering(cycle, variables_to_cluster)
# Out:
# c:\Users\canal\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\preprocessing\_data.py:461: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# c:\Users\canal\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\preprocessing\_data.py:462: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)

# %%
ut.TemporalCluster(cycle, kMeans_labels, variables_to_cluster, variable_to_plot_1,True)
# Out:
# c:\Users\canal\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\preprocessing\_data.py:461: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# c:\Users\canal\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\preprocessing\_data.py:462: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)
# Counter({0: 277, 1: 201})
# [0, 1]

# %%
ut.TemporalCluster(cycle, kMeans_labels, variables_to_cluster, variavle_to_plot_2,True)
# Out:
# c:\Users\canal\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\preprocessing\_data.py:461: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# c:\Users\canal\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\preprocessing\_data.py:462: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)
# Counter({0: 277, 1: 201})
# [0, 1]
